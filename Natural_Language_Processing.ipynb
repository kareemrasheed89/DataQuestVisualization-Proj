# %% [markdown]
# <a href="https://colab.research.google.com/github/kareemrasheed89/DataQuestVisualization-Proj/blob/master/Natural_Language_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import needed libraries
import requests
import json

from google.cloud import language
from google.oauth2 import service_account
from google.cloud.language import enums
from google.cloud.language import types

# Build language API client (requires service account key)
client = language.LanguageServiceClient.from_service_account_json('/content/image-classification-288410-72948dec7680.json')

# Define functions
def pull_googlenlp(client, url, invalid_types = ['OTHER'], **data):
   
        html = load_text_from_url(url, **data)
   
        if not html:
          return None
   
        document = types.Document(
        content=html,
        type=language.enums.Document.Type.HTML )

        features = {'extract_syntax': True,
                'extract_entities': True,
                'extract_document_sentiment': True,
                'extract_entity_sentiment': True,
                'classify_text': False
                }
   
        response = client.annotate_text(document=document, features=features)
        sentiment = response.document_sentiment
        entities = response.entities
   
        response = client.classify_text(document)
        categories = response.categories
         
        def get_type(type):
          return client.enums.Entity.Type(entity.type).name
   
        result = {}
   
        result['sentiment'] = []    
        result['entities'] = []
        result['categories'] = []

        if sentiment:
          result['sentiment'] = [{ 'magnitude': sentiment.magnitude, 'score':sentiment.score }]
         
        for entity in entities:
          if get_type(entity.type) not in invalid_types:
                result['entities'].append({'name': entity.name, 'type': get_type(entity.type), 'salience': entity.salience, 'wikipedia_url': entity.metadata.get('wikipedia_url', '-')  })
         
        for category in categories:
          result['categories'].append({'name':category.name, 'confidence': category.confidence})
         
         
        return result


def load_text_from_url(url, **data):

        timeout = data.get('timeout', 20)
   
        results = []
   
        try:
         
          print("Extracting text from: {}".format(url))
          response = requests.get(url, timeout=timeout)

          text = response.text
          status = response.status_code

          if status == 200 and len(text) > 0:
                return text
         
          return None
         

        except Exception as e:
          print('Problem with url: {0}.'.format(url))
        return None

# %%
url = "https://opensource.com/article/19/6/how-ssh-running-container"
pull_googlenlp(client,url)
# Out:
# Extracting text from: https://opensource.com/article/19/6/how-ssh-running-container
# {'categories': [{'confidence': 0.9399999976158142,
#    'name': '/Computers & Electronics/Programming'},
#   {'confidence': 0.9200000166893005, 'name': '/Science/Computer Science'},
#   {'confidence': 0.5, 'name': '/Computers & Electronics/Software'}],
#  'entities': [{'name': 'SSH',
#    'salience': 0.03275073692202568,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Ssh_(Secure_Shell)'},
#   {'name': 'Linux',
#    'salience': 0.022114111110568047,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Linux'},
#   {'name': 'comments',
#    'salience': 0.014860434457659721,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Seth Kenlon',
#    'salience': 0.010031153447926044,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Python',
#    'salience': 0.0074731698259711266,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Python_(programming_language)'},
#   {'name': 'DevOps',
#    'salience': 0.007204554043710232,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/DevOps'},
#   {'name': 'organization',
#    'salience': 0.0066736494190990925,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'open source tools',
#    'salience': 0.006476596929132938,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Red Hat',
#    'salience': 0.0048550693318247795,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Red_Hat'},
#   {'name': 'Open Source Yearbook',
#    'salience': 0.004039718769490719,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'collaboration tools',
#    'salience': 0.0037245340645313263,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Organizations',
#    'salience': 0.0036566564813256264,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Docker',
#    'salience': 0.00356381107121706,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Docker_(software)'},
#   {'name': 'hiring guide',
#    'salience': 0.0034705637954175472,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Articles',
#    'salience': 0.002867609728127718,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Software',
#    'salience': 0.0028063759673386812,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Open Organization',
#    'salience': 0.002781834453344345,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Containers',
#    'salience': 0.0026323336642235518,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Government',
#    'salience': 0.0026036251801997423,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Python template libraries',
#    'salience': 0.002560816938057542,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'Photos',
#    'salience': 0.002554557519033551,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'libraries',
#    'salience': 0.0025375401601195335,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'Introduction',
#    'salience': 0.0025366605259478092,
#    'type': 'EVENT',
#    'wikipedia_url': '-'},
#   {'name': 'Python GUI frameworks',
#    'salience': 0.002250333782285452,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Publisher',
#    'salience': 0.0022428142838180065,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Special Edition',
#    'salience': 0.00222928449511528,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Discourse software',
#    'salience': 0.002160280477255583,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'salience': 0.00214722310192883,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'salience': 0.002145964652299881,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Arduino',
#    'salience': 0.002009320305660367,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Arduino'},
#   {'name': 'container',
#    'salience': 0.0019054724834859371,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'container',
#    'salience': 0.00177427486050874,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Sysadmins',
#    'salience': 0.001764250104315579,
#    'type': 'PERSON',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/System_administrator'},
#   {'name': 'Building container images',
#    'salience': 0.0017100373515859246,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'organization',
#    'salience': 0.0016339953290298581,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'organization',
#    'salience': 0.0016289937775582075,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Microservices',
#    'salience': 0.0015152060659602284,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Microservices'},
#   {'name': 'AutoCAD',
#    'salience': 0.001511131995357573,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/AutoCAD'},
#   {'name': 'Photoshop',
#    'salience': 0.0015092395478859544,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Adobe_Photoshop'},
#   {'name': 'IRC',
#    'salience': 0.001503388280980289,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'desktop tools',
#    'salience': 0.001408337731845677,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Organizations',
#    'salience': 0.0013552242890000343,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Google',
#    'salience': 0.001325793913565576,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Google'},
#   {'name': 'Skype',
#    'salience': 0.0013250104384496808,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Skype'},
#   {'name': 'Trello',
#    'salience': 0.0013245085719972849,
#    'type': 'PERSON',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Trello'},
#   {'name': 'AWK',
#    'salience': 0.0013230904005467892,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/AWK'},
#   {'name': 'Emacs',
#    'salience': 0.0013222098350524902,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Emacs'},
#   {'name': 'FreeDOS',
#    'salience': 0.0013217870146036148,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/FreeDOS'},
#   {'name': 'Inkscape',
#    'salience': 0.001320581533946097,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Inkscape'},
#   {'name': 'style guide',
#    'salience': 0.001309707760810852,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Guide',
#    'salience': 0.0013087592087686062,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Guide',
#    'salience': 0.0013086445396766067,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Image',
#    'salience': 0.0011886764550581574,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'post',
#    'salience': 0.0010622896952554584,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Articles',
#    'salience': 0.0010470763081684709,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'oc',
#    'salience': 0.001025706180371344,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'team',
#    'salience': 0.0009573069983161986,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Book series',
#    'salience': 0.0009563208441250026,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Government',
#    'salience': 0.0009546428918838501,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Book series',
#    'salience': 0.0009528537048026919,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'oc',
#    'salience': 0.0009503094479441643,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'toolchain',
#    'salience': 0.0009305416606366634,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'comment',
#    'salience': 0.0009131683618761599,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'stack',
#    'salience': 0.0009111380204558372,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Leaders',
#    'salience': 0.0008397438796237111,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Educators',
#    'salience': 0.0008395962067879736,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'NIC',
#    'salience': 0.0008358873892575502,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'exec example',
#    'salience': 0.0008138106786645949,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Field Guide',
#    'salience': 0.0007733735255897045,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Field_guide'},
#   {'name': 'terminal',
#    'salience': 0.0007426463416777551,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'container app',
#    'salience': 0.0007084453827701509,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'tool',
#    'salience': 0.0006567426607944071,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'panel',
#    'salience': 0.0006485198391601443,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'world',
#    'salience': 0.0006415837560780346,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'state',
#    'salience': 0.0006415077950805426,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'introduction',
#    'salience': 0.0006412110524252057,
#    'type': 'EVENT',
#    'wikipedia_url': '-'},
#   {'name': 'machines',
#    'salience': 0.0006354761426337063,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'LXC',
#    'salience': 0.0006309705204330385,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/LXC'},
#   {'name': 'running container',
#    'salience': 0.000628642097581178,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'location',
#    'salience': 0.0005698325112462044,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'IT Culture Change',
#    'salience': 0.0005648311343975365,
#    'type': 'EVENT',
#    'wikipedia_url': '-'},
#   {'name': 'web console',
#    'salience': 0.0005088014877401292,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'forum',
#    'salience': 0.0004949187277816236,
#    'type': 'EVENT',
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'salience': 0.0004899644991382957,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'multimedia artist',
#    'salience': 0.0004899444174952805,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Terminal',
#    'salience': 0.0004783345793839544,
#    'type': 'EVENT',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Computer_terminal'},
#   {'name': 'docker exec',
#    'salience': 0.000427562597906217,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'COMMAND',
#    'salience': 0.0004007155366707593,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'free culture advocate',
#    'salience': 0.0003924194606952369,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'film',
#    'salience': 0.0003924034535884857,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Jenkins',
#    'salience': 0.0003832837683148682,
#    'type': 'PERSON',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Jenkins_(software)'},
#   {'name': 'Kubernetes Operators',
#    'salience': 0.0003787593450397253,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'salience': 0.00034220240195281804,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'author',
#    'salience': 0.00034220240195281804,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'bin/',
#    'salience': 0.00033871413324959576,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'OCI',
#    'salience': 0.00033291001454927027,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'name example-pod',
#    'salience': 0.00031745072919875383,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Team',
#    'salience': 0.0003121188492514193,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'newsletter',
#    'salience': 0.0002742430369835347,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Privacy Policy',
#    'salience': 0.00027414222131483257,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'employer',
#    'salience': 0.00027408316964283586,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'countries',
#    'salience': 0.0002740540076047182,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'exec',
#    'salience': 0.0002684009086806327,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'docker exec example',
#    'salience': 0.0002682561462279409,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'docker exec',
#    'salience': 0.0002681516343727708,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'Slackware',
#    'salience': 0.00026393873849883676,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Slackware'},
#   {'name': 'bin',
#    'salience': 0.0002572614175733179,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'bin',
#    'salience': 0.00025692657800391316,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'IMAGE',
#    'salience': 0.00024467898765578866,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'Ben Cotton',
#    'salience': 0.00023185591271612793,
#    'type': 'PERSON',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Ben_Cotton'},
#   {'name': 'D&D',
#    'salience': 0.00023181771393865347,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'UNIX',
#    'salience': 0.00023181771393865347,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Unix'},
#   {'name': 'ClaraBDias',
#    'salience': 0.00023170611530076712,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'os-release',
#    'salience': 0.0001959455548785627,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'release',
#    'salience': 0.00019593695469666272,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': 'CentOS',
#    'salience': 0.00018587516387924552,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/CentOS'},
#   {'name': 'IRC',
#    'salience': 0.00018441893917042762,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'The EnterprisersProject.com',
#    'salience': 0.00018436566460877657,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'United States',
#    'salience': 0.00018433948571328074,
#    'type': 'LOCATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/United_States'},
#   {'name': 'Denys P',
#    'salience': 0.0001830458058975637,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'boot dev home',
#    'salience': 0.00017214613035321236,
#    'type': 'LOCATION',
#    'wikipedia_url': '-'},
#   {'name': 'session',
#    'salience': 0.00017202497110702097,
#    'type': 'EVENT',
#    'wikipedia_url': '-'},
#   {'name': 'VERSION_ID',
#    'salience': 0.00016952661098912358,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'GIMP 2.10.',
#    'salience': 0.00016207742737606168,
#    'type': 'CONSUMER_GOOD',
#    'wikipedia_url': '-'},
#   {'name': 'Mira Edorra',
#    'salience': 0.00016207115550059825,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'RSS',
#    'salience': 0.00016195571515709162,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': '-'},
#   {'name': 'Footer',
#    'salience': 0.00016194982163142413,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'CIO',
#    'salience': 0.0001619148242752999,
#    'type': 'ORGANIZATION',
#    'wikipedia_url': 'https://en.wikipedia.org/wiki/Chief_information_officer'},
#   {'name': 'ID_LIKE',
#    'salience': 0.00014888909936416894,
#    'type': 'PERSON',
#    'wikipedia_url': '-'},
#   {'name': 'VERSION',
#    'salience': 0.000115734372229781,
#    'type': 'WORK_OF_ART',
#    'wikipedia_url': '-'},
#   {'name': '2015', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '2016', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '2017', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '2018', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '20 Jun 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '28 Jun 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '28 Jun 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '17 Jul 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '30 Jul 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '17 Sep 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '17 Sep 2019',
#    'salience': 0.0,
#    'type': 'DATE',
#    'wikipedia_url': '-'},
#   {'name': '2020', 'salience': 0.0, 'type': 'DATE', 'wikipedia_url': '-'},
#   {'name': '7', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2016', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '5', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '1', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '678', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '1', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '7', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '17', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '6', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '3', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2018', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '20', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '6', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '214', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': 'one', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '17', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '28', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '4', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2017', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '1', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2020', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '6', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '3', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '3.7', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '7', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '28', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '1', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '30', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '17', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2015', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2019', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '1', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '7.6', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '7', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'},
#   {'name': '2.10', 'salience': 0.0, 'type': 'NUMBER', 'wikipedia_url': '-'}],
#  'sentiment': [{'magnitude': 73.4000015258789, 'score': 0.0}]}
